# %% [markdown]
# ### Task 1

# %%
file = open(r"Student.txt", "w")

file.write("Name: Atika Mughal\n")
file.write("Program: BS-AI\n")
file.write("Semester: 4th\n")

file.close()

# %% [markdown]
# ### Task 2

# %%
students = ["Atika", "Ayesha", "Maham", "Tasmia", "Tooba"]
with open("Student.txt", "w") as file:
    file.writelines([name + "\n" for name in students])

# %% [markdown]
# ### Task 3

# %%
with open(r"Student.txt", "r") as file:
    content = file.read()
    print(content)
    
print()

with open(r"Student.txt", "r") as file:
    line1 = file.readline()
    print(line1)
print()

with open("Student.txt", "r") as file:
    lines = file.readlines()
    print(lines)
# Out:
# Atika
# Ayesha
# Maham
# Tasmia
# Tooba
#
#
# Atika
#
#
# ['Atika\n', 'Ayesha\n', 'Maham\n', 'Tasmia\n', 'Tooba\n']

# %% [markdown]
# ### Task 4

# %%
with open("data.txt", "r") as file:
    content = file.read()
    print(content)
print()

lines = content.split("\n")
t_lines = len(lines)
print("Total lines:", t_lines)

words = content.split()
t_words = len(words)
print("Total words:", t_words)

t_characters = len(content)
print("Total characters:", t_characters)
# Out:
# Artificial Intelligence
# I am Atika Mughal
# I am learning file handling in python
#
# Total lines: 3
# Total words: 13
# Total characters: 79

# %% [markdown]
# ### Task 5

# %%
word = input("Enter any word:")
with open("data.txt", "r") as file:
    lines = file.readlines()

count = 0
line_numbers = []

for i, line in enumerate(lines, start=1):
    if word in line:
        count += line.count(word)
        line_numbers.append(i)

if count > 0:
    print("Word found!")
    print("Number of occurence:", count)
    print("Line number:", line_numbers)
else:
    print("Word not found.")
# Out:
# Enter any word: Atika
# Word found!
# Number of occurence: 1
# Line number: [2]

# %% [markdown]
# ### Task 6

# %%
with open("source.txt", "r") as source_file:
    data = source_file.read()

with open("destination.txt", "w") as destination_file:
    destination_file.write(data)

print("Data copied!")
# Out:
# Data copied!

# %% [markdown]
# ### Task 7

# %%
while True:
    print("1. Add student")
    print("2. View all students")
    print("3. Search student")
    print("4. Exit")
    
    choice = input("Enter choice: ")
    
    if choice == "1":
        name = input("Enter name: ")
        program = input("Enter program: ")
        semester = input("Enter semester: ")
        file = open("students.txt", "a")
        file.write(name + "," + program + "," + semester + "\n")
        file.close()
        print("Record added!\n")
        
    elif choice == "2":
        file = open("students.txt", "r")
        data = file.read()
        file.close()
        if data == "":
            print("No records found.\n")
        else:
            print("\nAll Students:\n" + data)
            
    elif choice == "3":
        search_name = input("Enter name to search: ")
        file = open("students.txt", "r")
        lines = file.readlines()
        file.close()
        found = False
        for i in range(len(lines)):
            if search_name in lines[i]:
                print("Found at line", i+1, ":", lines[i].strip())
                found = True
        if not found:
            print("Student not found.\n")
            
    elif choice == "4":
        print("Goodbye!")
        break
        
    else:
        print("Invalid choice!\n")
# Out:
# 1. Add student
# 2. View all students
# 3. Search student
# 4. Exit
# Enter choice:  1
# Enter name:  atika
# Enter program:  Ai
# Enter semester:  4th
# Record added!
#
# 1. Add student
# 2. View all students
# 3. Search student
# 4. Exit
# Enter choice:  2
# All Students:
# atika,Ai,4th
#
# 1. Add student
# 2. View all students
# 3. Search student
# 4. Exit
# Enter choice:  3
# Enter name to search:  atika
# Found at line 1 : atika,Ai,4th
# 1. Add student
# 2. View all students
# 3. Search student
# 4. Exit
# Enter choice:  4
# Goodbye!
